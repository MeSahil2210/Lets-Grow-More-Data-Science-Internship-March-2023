# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\sahil\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\sahil\anaconda3\lib\site-packages (from opencv-python) (1.21.5)

# %%
import cv2
from PIL import Image
from IPython.display import display

# %%
image = cv2.imread('C:\\Users\\sahil\\Downloads\\viratkohli-1540363340.jpg')
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=950x634 at 0x2E18C3DCA90>

# %% [markdown]
# ### convert image to a grayscale image

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_image))
# Out:
# <PIL.Image.Image image mode=L size=950x634 at 0x2E18C29CAC0>

# %% [markdown]
# ### invert grayscale image(Negative image)

# %%
inverted_image = cv2.bitwise_not(gray_image)
display(Image.fromarray(inverted_image))
# Out:
# <PIL.Image.Image image mode=L size=950x634 at 0x2E18C2C9220>

# %% [markdown]
# ### convert Negative image into blurry image

# %%
blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)
display(Image.fromarray(blurred_image))
# Out:
# <PIL.Image.Image image mode=L size=950x634 at 0x2E18C42F940>

# %% [markdown]
# ### Create the pencil sketch by mixing the grayscale image with the inverted blurry image

# %%
inverted_blurred = cv2.bitwise_not(blurred_image)
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=250.0)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=950x634 at 0x2E18AA4E940>
